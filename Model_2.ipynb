# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.base import clone
from xgboost import XGBRFRegressor,XGBRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
def model_train(model,df):
    dict_score = {}
    tmp = pd.get_dummies(data = df, columns = ['Brand','Body','Engine_Type','Registration','Model'])
    X = tmp[tmp.columns[tmp.columns != "Price"]]
    y = tmp.Price
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
    print('Doing Model Train on whole data')
    model = RandomForestRegressor()
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    y_pred_train = model.predict(X_train)
    model.score(X_train,y_train),model.score(X_test,y_test)
    print('MAE,MSE and Rsquare for Test Data')
    print(mean_absolute_error(y_test,y_pred), mean_squared_error(y_test,y_pred), r2_score(y_test,y_pred))
    print('MAE,MSE and Rsquare for Train Data')
    print(mean_absolute_error(y_pred_train,y_train), mean_squared_error(y_pred_train,y_train),r2_score(y_pred_train,y_train))
    print("============="*5,"\n")
    for i in df.Brand.unique():
        print('Model for {} ===>'.format(i))
        tmp = df[df.Brand == i]
        tmp = pd.get_dummies(data = tmp, columns = ['Body','Engine_Type','Registration','Model'])
        tmp  =tmp.drop(['Brand'],axis =1)
        X = tmp[tmp.columns[tmp.columns != "Price"]]
        y = tmp.Price
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
        model = clone(model)
        model.fit(X_train,y_train)
        y_pred = model.predict(X_test)
        y_pred_train = model.predict(X_train)
        model.score(X_train,y_train),model.score(X_test,y_test)
        print('MAE,MSE and Rsquare for Test Data')
        print(mean_absolute_error(y_test,y_pred), mean_squared_error(y_test,y_pred), r2_score(y_test,y_pred))
        print('MAE,MSE and Rsquare for Train Data')
        print(mean_absolute_error(y_pred_train,y_train), mean_squared_error(y_pred_train,y_train),r2_score(y_pred_train,y_train))
        print("============="*5,"\n")

# %%
df = pd.read_csv('Train.csv')
df.columns =['Brand', 'Price', 'Body', 'Mileage', 'EngineV', 'Engine_Type',
       'Registration', 'Year', 'Model']

# %%
df.dropna(inplace = True)
df.drop_duplicates(inplace = True)
df = df.reset_index().drop('index',axis =1)

# %%
model = RandomForestRegressor()
model_train(model,df)
# Out:
# Doing Model Train on whole data
# MAE,MSE and Rsquare for Test Data
# 3052.6463311195967 87620883.30791901 0.8246409772595743
# MAE,MSE and Rsquare for Train Data
# 1214.4506821457019 12816018.034132222 0.9794464351324312
# =================================================================
#
# Model for BMW ===>
# MAE,MSE and Rsquare for Test Data
# 3170.5176091229678 34589343.94145363 0.9242248475020556
# MAE,MSE and Rsquare for Train Data
# 1168.568416118916 4357024.355969226 0.9915459564693185
# =================================================================
#
# Model for Mercedes-Benz ===>
# MAE,MSE and Rsquare for Test Data
# 5641.73795003131 192905549.7441613 0.8926718297853505
# MAE,MSE and Rsquare for Train Data
# 2874.557325542643 73881741.68111199 0.9520441429889538
# =================================================================
#
# Model for Audi ===>
# MAE,MSE and Rsquare for Test Data
# 2673.3376366906477 23229265.60278623 0.9404298249605696
# MAE,MSE and Rsquare for Train Data
# 1170.876267261905 5217004.854495197 0.9835366490023233
# =================================================================
#
# Model for Toyota ===>
# MAE,MSE and Rsquare for Test Data
# 3358.2222386833046 93640292.93322729 0.8433180740383305
# MAE,MSE and Rsquare for Train Data
# 1028.8752779920871 4666917.986515076 0.9838225983072248
# =================================================================
#
# Model for Renault ===>
# MAE,MSE and Rsquare for Test Data
# 1141.7449936183996 2585841.3364124238 0.7843929383102202
# MAE,MSE and Rsquare for Train Data
# 412.0528997265123 339416.7220528945 0.9697028567893066
# =================================================================
#
# Model for Volkswagen ===>
# MAE,MSE and Rsquare for Test Data
# 1659.6681377025461 7667712.790981127 0.9224702595786533
# MAE,MSE and Rsquare for Train Data
# 734.3399207914727 1557588.6432853993 0.986218668821641
# =================================================================
#
# Model for Mitsubishi ===>
# MAE,MSE and Rsquare for Test Data
# 1537.9487442244222 6807224.493339495 0.8612348158887075
# MAE,MSE and Rsquare for Train Data
# 705.1912560975608 1614735.7371972064 0.9622661908898337
# =================================================================

# %%
model = XGBRFRegressor()
model_train(model,df)
# Out:
# Doing Model Train on whole data
# MAE,MSE and Rsquare for Test Data
# 3056.740723148317 88945781.67389691 0.8219894075205225
# MAE,MSE and Rsquare for Train Data
# 1232.6488069167733 13160160.205270633 0.9787178600857547
# =================================================================
#
# Model for BMW ===>
# MAE,MSE and Rsquare for Test Data
# 3206.2777648589454 35274895.58248993 0.9227230040374133
# MAE,MSE and Rsquare for Train Data
# 1175.3270197502275 4754492.662642984 0.990700982330953
# =================================================================
#
# Model for Mercedes-Benz ===>
# MAE,MSE and Rsquare for Test Data
# 5656.308847026349 203148691.38036382 0.8869727835395523
# MAE,MSE and Rsquare for Train Data
# 2849.8503141151728 80936555.23974341 0.9472974065905886
# =================================================================
#
# Model for Audi ===>
# MAE,MSE and Rsquare for Test Data
# 2635.4557158273383 23651956.523424607 0.9393458573242021
# MAE,MSE and Rsquare for Train Data
# 1166.274510119048 5486326.162130264 0.982237050961594
# =================================================================
#
# Model for Toyota ===>
# MAE,MSE and Rsquare for Test Data
# 3281.415833476765 93705269.81127526 0.8432093526527321
# MAE,MSE and Rsquare for Train Data
# 1012.4328180726294 4600629.034272452 0.9839748045548502
# =================================================================
#
# Model for Renault ===>
# MAE,MSE and Rsquare for Test Data
# 1148.3855220278588 2638041.8446751153 0.780040467782834
# MAE,MSE and Rsquare for Train Data
# 413.16130820999575 345968.4540881089 0.9690969514991978
# =================================================================
#
# Model for Volkswagen ===>
# MAE,MSE and Rsquare for Test Data
# 1670.0296827215611 7963010.490373177 0.9194844469113067
# MAE,MSE and Rsquare for Train Data
# 702.0753752654579 1376099.1302747533 0.9879418153568921
# =================================================================
#
# Model for Mitsubishi ===>
# MAE,MSE and Rsquare for Test Data
# 1509.3014952852425 6390393.078410676 0.8697319189433466
# MAE,MSE and Rsquare for Train Data
# 668.4078556329848 1505805.6652354612 0.965405651841408
# =================================================================

# %%
model = XGBRegressor()
model_train(model,df)
# Out:
# Doing Model Train on whole data
# MAE,MSE and Rsquare for Test Data
# 3041.38392265746 86745142.72730748 0.8263936303554178
# MAE,MSE and Rsquare for Train Data
# 1206.2319076646922 11891972.962925876 0.9810516504743592
# =================================================================
#
# Model for BMW ===>
# MAE,MSE and Rsquare for Test Data
# 3183.38015223081 36223437.13698692 0.9206450264653522
# MAE,MSE and Rsquare for Train Data
# 1173.3918147446286 4412125.569714015 0.9913618315190441
# =================================================================
#
# Model for Mercedes-Benz ===>
# MAE,MSE and Rsquare for Test Data
# 5507.028052096436 189940114.42465305 0.8943217291643721
# MAE,MSE and Rsquare for Train Data
# 2842.320973072448 64978155.99073776 0.958318546948432
# =================================================================
#
# Model for Audi ===>
# MAE,MSE and Rsquare for Test Data
# 2607.3435371702635 23020098.549865797 0.9409662223726969
# MAE,MSE and Rsquare for Train Data
# 1124.8576321428573 4706396.122013296 0.9851788253404054
# =================================================================
#
# Model for Toyota ===>
# MAE,MSE and Rsquare for Test Data
# 3365.552457314974 93868985.9709927 0.8429354175505228
# MAE,MSE and Rsquare for Train Data
# 1062.216492320192 4673355.339412943 0.9835817957260538
# =================================================================
#
# Model for Renault ===>
# MAE,MSE and Rsquare for Test Data
# 1168.1627070942661 2694429.841404589 0.775338845096934
# MAE,MSE and Rsquare for Train Data
# 407.83195120656376 347658.07007253513 0.9683990824836007
# =================================================================
#
# Model for Volkswagen ===>
# MAE,MSE and Rsquare for Test Data
# 1705.418854176061 8104552.731518762 0.9180532856884215
# MAE,MSE and Rsquare for Train Data
# 727.7809121630727 1430964.5892515506 0.9874429759154991
# =================================================================
#
# Model for Mitsubishi ===>
# MAE,MSE and Rsquare for Test Data
# 1460.411870815653 6170933.196105762 0.8742056058333383
# MAE,MSE and Rsquare for Train Data
# 716.89172601626 1756186.5062670696 0.9584685867455887
# =================================================================

# %%
model = KNeighborsRegressor()
model_train(model,df)
# Out:
# Doing Model Train on whole data
# MAE,MSE and Rsquare for Test Data
# 3073.3883092412448 87519240.3345747 0.8248443992270458
# MAE,MSE and Rsquare for Train Data
# 1235.8747209467806 13637492.961215299 0.9780474081939711
# =================================================================
#
# Model for BMW ===>
# MAE,MSE and Rsquare for Test Data
# 3235.897688836283 35074307.665934265 0.9231624335909768
# MAE,MSE and Rsquare for Train Data
# 1172.3310291573225 4697544.732782659 0.9907955766376749
# =================================================================
#
# Model for Mercedes-Benz ===>
# MAE,MSE and Rsquare for Test Data
# 5462.997300774277 199964306.83922523 0.8887445011833086
# MAE,MSE and Rsquare for Train Data
# 2754.5308094491897 63562038.781008825 0.9589618153748618
# =================================================================
#
# Model for Audi ===>
# MAE,MSE and Rsquare for Test Data
# 2582.035751798562 23721411.035157535 0.9391677450458392
# MAE,MSE and Rsquare for Train Data
# 1121.0480704931977 4896243.3204005 0.9843286822787761
# =================================================================
#
# Model for Toyota ===>
# MAE,MSE and Rsquare for Test Data
# 3315.377804417671 93083691.65171154 0.844249397062307
# MAE,MSE and Rsquare for Train Data
# 1042.7441669634022 5148440.862131877 0.9814694144281922
# =================================================================
#
# Model for Renault ===>
# MAE,MSE and Rsquare for Test Data
# 1130.59129569161 2630631.570865653 0.7806583352984765
# MAE,MSE and Rsquare for Train Data
# 414.84752556306313 337388.345612519 0.9695948625187486
# =================================================================
#
# Model for Volkswagen ===>
# MAE,MSE and Rsquare for Test Data
# 1687.458372201554 8148758.468675537 0.917606312853063
# MAE,MSE and Rsquare for Train Data
# 720.9791740739606 1475813.314113638 0.9868805251027565
# =================================================================
#
# Model for Mitsubishi ===>
# MAE,MSE and Rsquare for Test Data
# 1479.706805280528 6286766.466873386 0.8718443460923073
# MAE,MSE and Rsquare for Train Data
# 695.1326674796746 1671010.6272613262 0.9605912821768219
# =================================================================
